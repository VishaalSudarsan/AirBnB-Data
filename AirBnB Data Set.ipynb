# %%
import pandas as pd

# %%
data = pd.read_csv("Airbnb_Open_Data.csv")
# Out:
# /var/folders/x_/gwkqp09d2zg11_0_2fs4pdy00000gn/T/ipykernel_64553/180275767.py:1: DtypeWarning: Columns (0: license) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("Airbnb_Open_Data.csv")

# %%
data.head ()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee minimum nights  \
# ...

# %%
data.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='str')

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  str
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  str
#  4   host name                       102193 non-null  str
#  5   neighbourhood group             102570 non-null  str
#  6   neighbourhood                   102583 non-null  str
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  str
#  10  country code                    102468 non-null  str
#  11  instant_bookable                102494 non-null  object
# ...

# %%
#Deleting redundant columns
data.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='str')

# %%
columns_to_keep = ['NAME', 'host id', 'host_identity_verified', 'host name',
       'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
       'country code', 'instant_bookable', 'cancellation_policy', 'room type',
       'Construction year', 'price', 'service fee', 'minimum nights',
       'number of reviews', 'last review']

columns_to_drop = ['id','reviews per month',
       'review rate number', 'calculated host listings count',
       'availability 365', 'house_rules', 'license']

# %%
len(columns_to_keep)
# Out:
# 19

# %%
len(columns_to_drop)
# Out:
# 7

# %%
#Filtering Data
data[columns_to_keep]
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %%
data.shape #notice that the 'data' still has all the 26 columns instead of just the 19 filtered ones
# Out:
# (102599, 26)

# %%
df = data[columns_to_keep] #we store our filtered data into a dataframe to have the clean data

# %%
df
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %%
# Dropping columns
data.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='str')

# %%
data.drop(columns = ['license']) #this wont drop this columns from the original data
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
# To drop the license col from the original df, we need to set data = data.drop (columns = ["license"]) or data.drop (columns = ['license'], inplace = True)

# %%
data.drop(columns = columns_to_drop, inplace = True) #now this will alter the df

# %%
data.shape
# Out:
# (102599, 19)

# %%
# Renaming the columns

# %%
data.columns
# Out:
# Index(['NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review'],
#       dtype='str')

# %%
# the inplace function ensures that the changes have been made to the original data as well data.rename(columns = {"NAME": "Name"}, inplace = True)

# %%
new_column_names = []
for i in data.columns:
    new_column_names.append (i.upper())

# %%
new_column_names
# Out:
# ['NAME',
#  'HOST ID',
#  'HOST_IDENTITY_VERIFIED',
#  'HOST NAME',
#  'NEIGHBOURHOOD GROUP',
#  'NEIGHBOURHOOD',
#  'LAT',
#  'LONG',
#  'COUNTRY',
#  'COUNTRY CODE',
#  'INSTANT_BOOKABLE',
#  'CANCELLATION_POLICY',
#  'ROOM TYPE',
#  'CONSTRUCTION YEAR',
#  'PRICE',
#  'SERVICE FEE',
#  'MINIMUM NIGHTS',
#  'NUMBER OF REVIEWS',
#  'LAST REVIEW']

# %%
new_dataframe_to_modify = data.copy()

# %%
new_dataframe_to_modify
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %%
new_dataframe_to_modify.columns
# Out:
# Index(['NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review'],
#       dtype='str')

# %%
new_dataframe_to_modify.columns = new_column_names

# %%
type (new_column_names)
# Out:
# list

# %%
new_dataframe_to_modify #uppercase col names in a data copy, no changes in the original data
# Out:
#                                                     NAME      HOST ID  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        HOST_IDENTITY_VERIFIED    HOST NAME NEIGHBOURHOOD GROUP  \
# ...

# %%
new_dataframe_to_modify.columns
# Out:
# Index(['NAME', 'HOST ID', 'HOST_IDENTITY_VERIFIED', 'HOST NAME',
#        'NEIGHBOURHOOD GROUP', 'NEIGHBOURHOOD', 'LAT', 'LONG', 'COUNTRY',
#        'COUNTRY CODE', 'INSTANT_BOOKABLE', 'CANCELLATION_POLICY', 'ROOM TYPE',
#        'CONSTRUCTION YEAR', 'PRICE', 'SERVICE FEE', 'MINIMUM NIGHTS',
#        'NUMBER OF REVIEWS', 'LAST REVIEW'],
#       dtype='str')

# %%
data.duplicated ()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 102594     True
# 102595     True
# 102596     True
# 102597     True
# 102598     True
# Length: 102599, dtype: bool

# %%
data.duplicated (). sum()
# Out:
# np.int64(541)

# %%
# Can use this to drop duplicates data = data.drop_duplicates () , or

# %%
data.drop_duplicates ( inplace = True)

# %%
data.duplicated ().sum()
# Out:
# np.int64(0)

# %%
#Removing NaN values

# %%
data.isna()
# Out:
#          NAME  host id  host_identity_verified  host name  \
# 0       False    False                   False      False
# 1       False    False                   False      False
# 2       False    False                    True      False
# 3        True    False                   False      False
# 4       False    False                   False      False
# ...       ...      ...                     ...        ...
# 102053  False    False                   False      False
# 102054  False    False                   False      False
# 102055  False    False                   False      False
# 102056  False    False                   False      False
# 102057  False    False                   False      False
#
#         neighbourhood group  neighbourhood    lat   long  country  \
# 0                     False          False  False  False    False
# 1                     False          False  False  False    False
# 2                     False          False  False  False    False
# ...

# %%
data.isna().sum()
# Out:
# NAME                        250
# host id                       0
# host_identity_verified      289
# host name                   404
# neighbourhood group          29
# neighbourhood                16
# lat                           8
# long                          8
# country                     532
# country code                131
# instant_bookable            105
# cancellation_policy          76
# room type                     0
# Construction year           214
# price                       247
# service fee                 273
# minimum nights              400
# number of reviews           183
# last review               15832
# dtype: int64

# %%
#The col 'last review' has a lot of missing values. Drop this col
data.drop (columns = ["last review"], inplace = True)

# %%
data.isna().sum()
# Out:
# NAME                      250
# host id                     0
# host_identity_verified    289
# host name                 404
# neighbourhood group        29
# neighbourhood              16
# lat                         8
# long                        8
# country                   532
# country code              131
# instant_bookable          105
# cancellation_policy        76
# room type                   0
# Construction year         214
# price                     247
# service fee               273
# minimum nights            400
# number of reviews         183
# dtype: int64

# %%
#modified the original data to drop all the NA rows
data.dropna(inplace = True)

# %%
data.isna().sum()
# Out:
# NAME                      0
# host id                   0
# host_identity_verified    0
# host name                 0
# neighbourhood group       0
# neighbourhood             0
# lat                       0
# long                      0
# country                   0
# country code              0
# instant_bookable          0
# cancellation_policy       0
# room type                 0
# Construction year         0
# price                     0
# service fee               0
# minimum nights            0
# number of reviews         0
# dtype: int64

# %%
data.columns
# Out:
# Index(['NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews'],
#       dtype='str')

# %%
data['host_identity_verified'].str.upper()
# Out:
# 0         UNCONFIRMED
# 1            VERIFIED
# 4            VERIFIED
# 5            VERIFIED
# 7         UNCONFIRMED
#              ...
# 102029    UNCONFIRMED
# 102030       VERIFIED
# 102031       VERIFIED
# 102032    UNCONFIRMED
# 102040       VERIFIED
# Name: host_identity_verified, Length: 99342, dtype: str

# %%
data #the above op did not change the original data
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5              Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                        BlissArtsSpace!  90821839709
# ...                                                  ...          ...
# 102029            Cozy room in a 2B with backyard access   5155155913
# 102030                      An East Williamsburg Delight  71564706996
# 102031                      Cozy bedroom in williamsburg  83101851929
# 102032                            Spacious Room w/ 2 Bed  69037598918
# 102040                     Room in Queens, NY, near LGA.  56457739998
#
#        host_identity_verified  host name neighbourhood group  \
# 0                 unconfirmed   Madaline            Brooklyn
# ...

# %%
data['host_identity_verified'] = data['host_identity_verified'].str.upper() #now we modify the original data

# %%
data
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5              Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                        BlissArtsSpace!  90821839709
# ...                                                  ...          ...
# 102029            Cozy room in a 2B with backyard access   5155155913
# 102030                      An East Williamsburg Delight  71564706996
# 102031                      Cozy bedroom in williamsburg  83101851929
# 102032                            Spacious Room w/ 2 Bed  69037598918
# 102040                     Room in Queens, NY, near LGA.  56457739998
#
#        host_identity_verified  host name neighbourhood group  \
# 0                 UNCONFIRMED   Madaline            Brooklyn
# ...

# %%
data['instant_bookable']
# Out:
# 0         False
# 1         False
# 4         False
# 5          True
# 7         False
#           ...
# 102029    False
# 102030     True
# 102031     True
# 102032    False
# 102040     True
# Name: instant_bookable, Length: 99342, dtype: object

# %%
#converting col bool values to numeric
data['instant_bookable'] = data['instant_bookable'].apply(lambda x:1 if x == True else 0)

# %%
data
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5              Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                        BlissArtsSpace!  90821839709
# ...                                                  ...          ...
# 102029            Cozy room in a 2B with backyard access   5155155913
# 102030                      An East Williamsburg Delight  71564706996
# 102031                      Cozy bedroom in williamsburg  83101851929
# 102032                            Spacious Room w/ 2 Bed  69037598918
# 102040                     Room in Queens, NY, near LGA.  56457739998
#
#        host_identity_verified  host name neighbourhood group  \
# 0                 UNCONFIRMED   Madaline            Brooklyn
# ...

# %%
data = data.reset_index() #resetting index after dropping rows earlier

# %%
type (data["instant_bookable"] [15])
# Out:
# numpy.int64

# %%
#Changing data type in col
type (data ["price"] [15])
# Out:
# str

# %%
data["price"] [15]
# Out:
# '$1,020 '

# %%
data["price"].head (5)
# Out:
# 0      $966
# 1      $142
# 2      $204
# 3      $577
# 4    $1,060
# Name: price, dtype: str

# %%
data ["price"].str.replace("$", "")
# Out:
# 0          966
# 1          142
# 2          204
# 3          577
# 4        1,060
#           ...
# 99337      822
# 99338      455
# 99339    1,078
# 99340      103
# 99341      982
# Name: price, Length: 99342, dtype: str

# %%
data ["price"] = data ["price"].str.replace("$", "") #replace $ sign with no space

# %%
data ["price"].str.replace(",", "")
# Out:
# 0         966
# 1         142
# 2         204
# 3         577
# 4        1060
#          ...
# 99337     822
# 99338     455
# 99339    1078
# 99340     103
# 99341     982
# Name: price, Length: 99342, dtype: str

# %%
data ["price"] = data ["price"].str.replace(",", "")  #replace comma sign with no space

# %%
data ["price"].str.replace(",", "")
# Out:
# 0         966
# 1         142
# 2         204
# 3         577
# 4        1060
#          ...
# 99337     822
# 99338     455
# 99339    1078
# 99340     103
# 99341     982
# Name: price, Length: 99342, dtype: str

# %%
data ["price"] = data ["price"].str.replace(" ", "")  #replace space with no space

# %%
 data ["price"]
# Out:
# 0         966
# 1         142
# 2         204
# 3         577
# 4        1060
#          ...
# 99337     822
# 99338     455
# 99339    1078
# 99340     103
# 99341     982
# Name: price, Length: 99342, dtype: str

# %%
type ( data ["price"])
# Out:
# pandas.Series

# %%
type ( data ["price"] [3])
# Out:
# str

# %%
data ["price"].astype(int)
# Out:
# 0         966
# 1         142
# 2         204
# 3         577
# 4        1060
#          ...
# 99337     822
# 99338     455
# 99339    1078
# 99340     103
# 99341     982
# Name: price, Length: 99342, dtype: int64

# %%
type (data ["price"].astype(int) [15])
# Out:
# numpy.int64

# %%
data ["price"] = data ["price"].astype(int)

# %%
data
# Out:
#         index                                              NAME      host id  \
# 0           0                Clean & quiet apt home by the park  80014485718
# 1           1                             Skylit Midtown Castle  52335172823
# 2           4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3           5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4           7                                   BlissArtsSpace!  90821839709
# ...       ...                                               ...          ...
# 99337  102029            Cozy room in a 2B with backyard access   5155155913
# 99338  102030                      An East Williamsburg Delight  71564706996
# 99339  102031                      Cozy bedroom in williamsburg  83101851929
# 99340  102032                            Spacious Room w/ 2 Bed  69037598918
# 99341  102040                     Room in Queens, NY, near LGA.  56457739998
#
# ...

# %%
data.rename(columns={'price': 'Price($)'}, inplace=True)

# %%
data
# Out:
#         index                                              NAME      host id  \
# 0           0                Clean & quiet apt home by the park  80014485718
# 1           1                             Skylit Midtown Castle  52335172823
# 2           4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3           5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4           7                                   BlissArtsSpace!  90821839709
# ...       ...                                               ...          ...
# 99337  102029            Cozy room in a 2B with backyard access   5155155913
# 99338  102030                      An East Williamsburg Delight  71564706996
# 99339  102031                      Cozy bedroom in williamsburg  83101851929
# 99340  102032                            Spacious Room w/ 2 Bed  69037598918
# 99341  102040                     Room in Queens, NY, near LGA.  56457739998
#
# ...

# %%
data.columns = data.columns.str.upper() 
#mistakenly ran the function to drop the index col but removed it. It doesnt show in the code but it was executed

# %%
data
# Out:
#         INDEX                                              NAME      HOST ID  \
# 0           0                Clean & quiet apt home by the park  80014485718
# 1           1                             Skylit Midtown Castle  52335172823
# 2           4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3           5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4           7                                   BlissArtsSpace!  90821839709
# ...       ...                                               ...          ...
# 99337  102029            Cozy room in a 2B with backyard access   5155155913
# 99338  102030                      An East Williamsburg Delight  71564706996
# 99339  102031                      Cozy bedroom in williamsburg  83101851929
# 99340  102032                            Spacious Room w/ 2 Bed  69037598918
# 99341  102040                     Room in Queens, NY, near LGA.  56457739998
#
# ...

# %%
data.to_csv("Cleaned_AirBnB_Data.csv", index=False)

# %%
data.to_csv("Cleaned_AirBnB_Data.csv")

# %%
pd.read_csv("Cleaned_AirBnB_Data.csv")
# Out:
#        Unnamed: 0   INDEX                                              NAME  \
# 0               0       0                Clean & quiet apt home by the park
# 1               1       1                             Skylit Midtown Castle
# 2               2       4  Entire Apt: Spacious Studio/Loft by central park
# 3               3       5         Large Cozy 1 BR Apartment In Midtown East
# 4               4       7                                   BlissArtsSpace!
# ...           ...     ...                                               ...
# 99337       99337  102029            Cozy room in a 2B with backyard access
# 99338       99338  102030                      An East Williamsburg Delight
# 99339       99339  102031                      Cozy bedroom in williamsburg
# 99340       99340  102032                            Spacious Room w/ 2 Bed
# 99341       99341  102040                     Room in Queens, NY, near LGA.
#
# ...

# %%
data.to_excel("Excel_cleaned.xlsx")

# %%
#Find Most Expensive Neighbourhood in the US
US_data = data[data['COUNTRY CODE'] == 'US']
US_data = US_data.groupby(['NEIGHBOURHOOD']).agg(avg_price = ('PRICE($)', 'mean'))
print("Most Expensive AirBnBNeighbourhood in the US is", US_data['avg_price'].idxmax())
# Out:
# Most Expensive AirBnBNeighbourhood in the US is New Dorp
